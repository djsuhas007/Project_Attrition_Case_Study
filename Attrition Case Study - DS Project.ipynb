# %%
#Import 'Pandas' library to read the data 
import pandas as pd

# %%
#Using 'read_excel' method as the file is in '.xlsx' format
df = pd.read_excel("E:/Data Science class/Datasets/Attrition Case Study.xlsx")

# %%
# To get the overall insights of the data
df.head()
# Out:
#    Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0          1   41      Travel_Rarely       1102                   Sales
# 1          0   49  Travel_Frequently        279  Research & Development
# 2          1   37      Travel_Rarely       1373  Research & Development
# 3          0   33  Travel_Frequently       1392  Research & Development
# 4          0   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# Original dataset has the 'Attrition' column in 'binary' format i.e. 0 & 1. So, we will replace these binary numbers with 'Yes' & 'No'

# %%
df['Attrition'].replace(to_replace=[0,1], value=["No","Yes"],inplace=True)

# %%
# For getting the information about number of rows & columns
df.shape
# Out:
# (1470, 35)

# %%
# To get the type of each columns in dataset; whether it is 'Categorical' or 'Continues'
df.dtypes
# Out:
# Attrition                   object
# Age                          int64
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1470 non-null   object
#  1   Age                       1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
A=df

# %%
#To get the statistics of the dataset i.e. mean, max, min, standard deviation etc.
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#Name of the columns
A.columns
# Out:
# Index(['Attrition', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
CAT = []  #categorical columns
CON = []  #continues columns
for i in A.columns:
    if A[i].dtypes=='object':
        CAT.append(i)
    else:
        CON.append(i)

# %%
CAT
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
CON
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
# We will import 'matplotlib' and 'seaborn' libraries for data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# To check number of missing values in each columns
df.isna().sum()
# Out:
# Attrition                   0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# To check if any of the columns in a dataset have missing values
df.isnull().values.any()
# Out:
# False

# %%
# To check the number of 'Attrition' values both 'Yes' & 'No'
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# We used countplot to visualize the number of attritions
sb.countplot(df['Attrition'])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
# To get the broader plot, we used subplots function with 'figsize' parameter
# Below graph shows the countplot of 'Age' with 'Attrition'
plt.subplots(figsize=(12,4))
sb.countplot(x='Age',hue='Attrition',data=df)
plt.ylabel = 'Attrition'
plt.title = 'Age vs Attrition'

# %%
# To get overall brief idea about the 'categorical' columns

for column in df.columns:
    if df[column].dtypes=='object':
        print(str(column)+' : '+ str(df[column].unique()))
        print(df[column].value_counts())
        print('******************************************************')
# Out:
# Attrition : ['Yes' 'No']
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ******************************************************
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ******************************************************
# Department : ['Sales' 'Research & Development' 'Human Resources']
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ******************************************************
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ...

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# We checked unique values in 'StandardHours' column & found that it is same throughout a column
df['StandardHours'].unique()
# Out:
# array([80], dtype=int64)

# %%
# Dropping 'Over18', 'EmployeeNumber' & 'StandardHours' columns as they are irrelevant
df = df.drop(['Over18','EmployeeNumber','StandardHours'],axis=1)

# %%
df.columns
# Out:
# Index(['Attrition', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df['EmployeeCount'].unique()
# Out:
# array([1], dtype=int64)

# %%
df = df.drop(['EmployeeCount'],axis=1)

# %%
# To get the co-relation between every columns
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %%
# To visualize the co-relation between features, we will plot the 'Heatmap'
plt.figure(figsize=(14,14))
sb.heatmap(df.corr() , annot=True, fmt = '.0%')
# Out:
# <AxesSubplot:>

# %%
# We will import LabelEncoder to convert the 'categorical' values into 'continues' for further process
from sklearn.preprocessing import LabelEncoder as le
import numpy as np

# %%
# Trnsforming the 'categorical' values into 'continues'
for column in df.columns:
    if df[column].dtype==np.number:
        continue
    df[column]=le().fit_transform(df[column])
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Splitting the data into X (Independant variable) & Y (Dependant variable)
# We are predicting 'Attrition', hence, it is the 'Y' column i.e. Target variable
X = df.drop(columns='Attrition',axis=1)
Y = df['Attrition']

# %%
X.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
Y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %%
# Using train_test_split method to split the data in training & teating set
from sklearn.model_selection import train_test_split

# %%
# 70% data in training & 30% data in testing set
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size = 0.3, random_state=1234)

# %%
# We will use 'Ensemble' method for classification & will use RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=1234)

# %%
# Fit the model
rfc.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=1234)

# %%
# Training data accuracy
rfc.score(X_train,Y_train)
# Out:
# 0.9795918367346939

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
Y_pred = rfc.predict(X_test)

# %%
# Creating the confusion matrix
cm = confusion_matrix(Y_test,Y_pred)

# %%
cm
# Out:
# array([[367,   4],
#        [ 60,  10]], dtype=int64)

# %%
Accuracy = accuracy_score(Y_test,Y_pred)
print("Model's testing accuracy score is : {} " .format(Accuracy))
# Out:
# Model's testing accuracy score is : 0.854875283446712
